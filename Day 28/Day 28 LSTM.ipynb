# %%
from tensorflow.keras.preprocessing.text import Tokenizer
import pandas as pd
max_words = 5000
max_len = 500
tokenizer = Tokenizer(num_words=max_words)  ## 使用的最大詞語數為5000
news = pd.read_excel('ETtoday news_202205.xlsx', engine = 'openpyxl')
# Out:
#       Unnamed: 0  level_0  index                              title  \
# 0              0        0      0         路燈下有貓？他想上前嚕貓　湊近一看「發現真相」超失望
# 1              1        1      1       高雄情侶逼幼貓跳床！養3週「地上慘死」她PO文討拍遭網轟
# 2              2        2      2      汪瞥見媽白目學「吐舌+喘氣」　捍衛專利板臉怒瞪母：不能學！
# 3              3        3      3        幼貓天生擁「超成熟爺爺臉」！　她曝悲傷原因：牠乖又堅強
# 4              4        4      4        鄰居貓兄弟「尾巴交叉」黏TT散步　網融化：根本是連體嬰
# ...          ...      ...    ...                                ...
# 7116        7116     7125   3082    防疫在家吃！添好運外帶餐盒200元有找　亞緻餐飲網購可包辦三餐
# 7117        7117     7126   3083      餐廳禁止內用！王品、饗賓衝刺外帶外送服務　瓦城增建雲端廚房
# 7118        7118     7127   3084         全台三級警戒延長！　九族文化村宣布「休園至6／14」
# 7119        7119     7128   3085  五星飯店成防疫旅館！桃園喜來登：損失上千萬...6／1起不再接預訂
# 7120        7120     7129   3086    宅在家也能玩世界！旅遊電商推雲端旅遊　專人帶你玩巴黎、拜四面佛
#
#                                                    link  category  \
# 0     https://www.ettoday.net/news/20210501/1967950.htm         1
# 1     https://www.ettoday.net/news/20210501/1972426.htm         1
# 2     https://www.ettoday.net/news/20210501/1968132.htm         1
# 3     https://www.ettoday.net/news/20210501/1967790.htm         1
# 4     https://www.ettoday.net/news/20210501/1967765.htm         1
# ...                                                 ...       ...
# 7116  https://www.ettoday.net/news/20210525/1990896.htm         2
# 7117  https://www.ettoday.net/news/20210525/1990902.htm         2
# 7118  https://www.ettoday.net/news/20210525/1990879.htm         2
# 7119  https://www.ettoday.net/news/20210525/1990892.htm         2
# 7120  https://www.ettoday.net/news/20210525/1990856.htm         2
#
#                                                 content  \
# 0      實習記者周依儒／綜合報導 晚上在路邊時，常常因為昏暗視線或光影折射，讓人容易眼花誤認。日前...
# 1      記者鄒鎮宇／綜合報導 一名在IG上有6000多名粉絲追蹤的女子，透過限時動態分享養貓經過，...
# 2      「你為什麼要一直學我！」一名外國網友在TikTok @thenicegirlx 分享，自己...
# 3      實習記者周依儒／綜合報導 美國流浪貓組織日前收到一起案件，一隻剛出生的喜馬拉雅貓因患有天生...
# 4      實習記者周依儒／綜合報導 超可愛！烏克蘭刺青師安妮（Annie）日前在自己的Tiktok帳...
# ...                                                 ...
# 7116   ▲防疫在家吃！添好運外帶餐盒XO醬臘味炒飯。（圖／和億生活集團提供） 記者黃士原／台北報導...
# 7117   ▲王品全集團20個品牌、280家門店「外帶滿599元現折100元」。（圖／王品提供） 記者...
# 7118   記者周姈姈／綜合報導 本土確診連環爆，指揮中心今（25）日宣布，全國三級警戒延長到6/14...
# 7119   記者彭懷玉／採訪報導 本土疫情嚴峻，截止今日已破4000例，國際五星連鎖「桃園喜來登酒店」...
# 7120   ▲KLOOK與MyProGuide合作，專人帶旅客線上漫遊花都巴黎。（圖／KLOOK提供）...
#
#                                            tokenization
# 0     實習 記者 周依儒 綜合 報導 晚上 在 路 邊 時 常常 因為 昏暗 視線 或 光影 折射...
# 1     記者 鄒鎮宇 綜合 報導 一 名 在 上 有 多 名 粉絲 追蹤 的 女子 透過 限時 動態...
# 2     你 為什麼 要 一直 學 我 一 名 外國 網友 在 分享 自己 學 起 家 中 羅威那犬 ...
# 3     實習 記者 周依儒 綜合 報導 美國 流浪貓 組織 日前 收到 一起 案件 一 隻 剛 出生...
# 4     實習 記者 周依儒 綜合 報導 超 可愛 烏克蘭 刺青師 安妮 日前 在 自己 的 帳號 上...
# ...                                                 ...
# 7116  防疫 在 家 吃添 好運 外帶 餐盒醬 臘味 炒飯 圖 和 億 生活 集團 提供 記者 黃士...
# 7117  王品全 集團 個 品牌 家門店 外帶 滿 元現 折元圖 王品 提供 記者 黃士原 台北 報導...
# 7118  記者 周姈姈 綜合 報導 本土 確診 連環 爆 指揮 中心 今日 宣布 全 國 三 級 警戒...
# 7119  記者 彭懷玉 採訪 報導 本土 疫情 嚴峻 截止 今日 已 破例 國際 五星 連鎖 桃園 喜...
# 7120  與 合作 專人 帶 旅客 線上 漫遊 花都 巴黎圖 提供 記者 蔡玟君 台北 報導 全 台 ...
#
# [7121 rows x 8 columns]

# %%
tokenizer.fit_on_texts(news['tokenization'])

## 使用word_index屬性可以看到每個詞對應的編碼
## 使用word_counts屬性可以看到每個詞對應的頻數
for index,item in enumerate(tokenizer.word_index.items()):
    if index < 10:
        print(item)
    else:
        break
print("===================")  
for index,item in enumerate(tokenizer.word_counts.items()):
    if index < 10:
        print(item)
    else:
        break
# Out:
# ('的', 1)
# ('是', 2)
# ('有', 3)
# ('在', 4)
# ('也', 5)
# ('一', 6)
# ('了', 7)
# ('就', 8)
# ('不', 9)
# ('都', 10)
# ===================
# ('實習', 1708)
# ('記者', 8023)
# ('周依儒', 51)
# ('綜合', 3054)
# ('報導', 6132)
# ('晚上', 472)
# ('在', 24798)
# ('路', 641)
# ('邊', 1522)
# ('時', 5709)

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
labelencoder = LabelEncoder()
le_y = labelencoder.fit_transform(news['category']).reshape(-1,1)
ohe = OneHotEncoder()
y = ohe.fit_transform(le_y).toarray()
x = news['tokenization']
#Split the data to have 20% validation split
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.2)

# %%
from sklearn import metrics
from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing import sequence

train_seq = tokenizer.texts_to_sequences(train_x)
test_seq = tokenizer.texts_to_sequences(test_x)
## 將每個序列調整相同的長度
train_seq_mat = sequence.pad_sequences(train_seq,maxlen=max_len)
test_seq_mat = sequence.pad_sequences(test_seq,maxlen=max_len)
# print(train_seq_mat.shape, test_seq_mat.shape)

# %%
inputs = Input(name='inputs',shape=[max_len])
## Embedding(詞匯表大小,vector長度,每個新聞的詞長)
layer = Embedding(max_words+1,128,input_length=max_len)(inputs)
layer = LSTM(128)(layer)
layer = Dense(128,activation="relu",name="FC1")(layer)
layer = Dropout(0.3)(layer)
layer = Dense(3,activation="softmax",name="FC2")(layer)
model = Model(inputs=inputs,outputs=layer)
model.summary()
## multi-classification problem use categorical_crossentropy
model.compile(loss="categorical_crossentropy",optimizer=RMSprop(),metrics=["accuracy"])
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 500)]             0
# _________________________________________________________________
# embedding (Embedding)        (None, 500, 128)          640128
# _________________________________________________________________
# lstm (LSTM)                  (None, 128)               131584
# _________________________________________________________________
# FC1 (Dense)                  (None, 128)               16512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# FC2 (Dense)                  (None, 3)                 387
# =================================================================
# Total params: 788,611
# Trainable params: 788,611
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_fit = model.fit(train_seq_mat,train_y,batch_size=128,epochs=10,
                      validation_split=0.2)
# Out:
# Epoch 1/10
# 36/36 [==============================] - 39s 1s/step - loss: 0.5035 - accuracy: 0.8099 - val_loss: 0.1735 - val_accuracy: 0.9018
# Epoch 2/10
# 36/36 [==============================] - 46s 1s/step - loss: 0.0973 - accuracy: 0.9726 - val_loss: 0.0268 - val_accuracy: 0.9921
# Epoch 3/10
# 36/36 [==============================] - 46s 1s/step - loss: 0.0125 - accuracy: 0.9980 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 4/10
# 36/36 [==============================] - 47s 1s/step - loss: 0.0034 - accuracy: 0.9996 - val_loss: 0.0071 - val_accuracy: 0.9974
# Epoch 5/10
# 36/36 [==============================] - 48s 1s/step - loss: 8.2840e-04 - accuracy: 0.9998 - val_loss: 0.0022 - val_accuracy: 0.9991
# Epoch 6/10
# 36/36 [==============================] - 50s 1s/step - loss: 0.0069 - accuracy: 0.9985 - val_loss: 0.0019 - val_accuracy: 0.9991
# Epoch 7/10
# 36/36 [==============================] - 51s 1s/step - loss: 1.9360e-04 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 0.9991
# Epoch 8/10
# 36/36 [==============================] - 53s 1s/step - loss: 1.2962e-05 - accuracy: 1.0000 - val_loss: 3.9796e-04 - val_accuracy: 1.0000
# Epoch 9/10
# 36/36 [==============================] - 51s 1s/step - loss: 5.4913e-06 - accuracy: 1.0000 - val_loss: 1.0797e-05 - val_accuracy: 1.0000
# Epoch 10/10
# 36/36 [==============================] - 50s 1s/step - loss: 1.1567e-06 - accuracy: 1.0000 - val_loss: 3.2404e-06 - val_accuracy: 1.0000

# %%
import numpy as np
test_pre = model.predict(test_seq_mat)
## evaluate the performance of prediction
confusion_matrix = metrics.confusion_matrix(np.argmax(test_pre,axis=1),np.argmax(test_y,axis=1))
print("Confusion matrix: \n",confusion_matrix)

scores = model.evaluate(test_seq_mat, test_y, verbose=0)
print("Out-of-sample loss: ", scores[0],"Out-of-sample accuracy:", scores[1])

print(metrics.classification_report(np.argmax(test_pre,axis=1),np.argmax(test_y,axis=1)))
# Out:
# Confusion matrix:
#  [[190   0   0]
#  [  0 610   0]
#  [  0   0 625]]
# Out-of-sample loss:  1.9725155198102584e-07 Out-of-sample accuracy: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       190
#            1       1.00      1.00      1.00       610
#            2       1.00      1.00      1.00       625
#
#     accuracy                           1.00      1425
#    macro avg       1.00      1.00      1.00      1425
# weighted avg       1.00      1.00      1.00      1425

# %%
# 繪製歷程圖
import matplotlib.pyplot as plt
def show_train_history(train_history):
    plt.figure(figsize=(6,5))
    plt.plot(train_history.history['accuracy'])
    plt.plot(train_history.history['val_accuracy'])
    plt.xticks([i for i in range(len(train_history.history['accuracy']))])
    plt.title('Train History')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['Train', 'Val'], loc='upper left')
    plt.savefig('Accuracy.png')
    plt.show()

    plt.figure(figsize=(6,5))
    plt.plot(train_history.history['loss'])
    plt.plot(train_history.history['val_loss'])
    plt.xticks([i for i in range(len(train_history.history['loss']))])
    plt.title('Train History')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['Train', 'Val'], loc='upper left')
    plt.savefig('Loss.png')
    plt.show()
show_train_history(model_fit)
